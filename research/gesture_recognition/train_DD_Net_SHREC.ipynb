# %%
! pip install -q keras

# %%
import numpy as np
import math
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
from tqdm import tqdm
import pickle
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt 
from scipy.spatial.distance import cdist

from keras.optimizers import *
from keras.models import Model
from keras.layers import *
from keras.layers.core import *
from tensorflow.keras.callbacks import *
from keras.layers.convolutional import *
from keras import backend as K
import keras
import tensorflow as tf

import google.colab.files

# %% [markdown]
# 1. Define configurations

# %%
random.seed(1234)

class Config():
    def __init__(self):
        self.frame_l = 32 # the length of frames
        self.joint_n = 12 # the number of joints
        self.joint_n = 22 # the number of joints
        self.joint_d = 3 # the dimension of joints
        self.clc_coarse = 14 # the number of coarse class
        self.clc_fine = 28 # the number of fine-grained class
        self.feat_d = 231
        self.filters = 64
C = Config()

# %% [markdown]
# 2. Define data processing functions

# %%
# Temple resizing function
import numpy as np
import os
import pandas as pd
import random
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt 

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

###################################################################################
    
    
#Rescale to be 64 frames
def zoom(p,target_l=64,joints_num=25,joints_dim=3):
    l = p.shape[0]
    p_new = np.empty([target_l,joints_num,joints_dim]) 
    for m in range(joints_num):
        for n in range(joints_dim):
            p[:,m,n] = medfilt(p[:,m,n],3)
            p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]         
    return p_new

def sampling_frame(p,C):
    full_l = p.shape[0] # full length
    if random.uniform(0,1)<0.5: # aligment sampling
        valid_l = np.round(np.random.uniform(0.9,1)*full_l)
        s = random.randint(0, full_l-int(valid_l))
        e = s+valid_l # sample end point
        p = p[int(s):int(e),:,:]    
    else: # without aligment sampling
        valid_l = np.round(np.random.uniform(0.9,1)*full_l)
        index = np.sort(np.random.choice(range(0,full_l),int(valid_l),replace=False))
        p = p[index,:,:]
    p = zoom(p,C.frame_l,C.joint_n,C.joint_d)
    return p

from scipy.spatial.distance import cdist
def get_CG(p,C):
    M = []
    iu = np.triu_indices(C.joint_n,1,C.joint_n)
    for f in range(C.frame_l):
        #distance max 
        d_m = cdist(p[f],np.concatenate([p[f],np.zeros([1,C.joint_d])]),'euclidean')       
        d_m = d_m[iu] 
        M.append(d_m)
    M = np.stack(M)   
    return M

def normlize_range(p):
    # normolize to start point, use the center for hand case
    p[:,:,0] = p[:,:,0]-np.mean(p[:,:,0])
    p[:,:,1] = p[:,:,1]-np.mean(p[:,:,1])
    p[:,:,2] = p[:,:,2]-np.mean(p[:,:,2])
    return p

def cm_analysis(y_true, y_pred, filename, labels, ymap=None, figsize=(8,8)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                #annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
                annot[i, j] = '%.1f' % (p)
            elif c == 0:
                annot[i, j] = ''
            else:
                #annot[i, j] = '%.1f%%\n%d' % (p, c)
                annot[i, j] = '%.1f' % (p)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax, cbar=False, cmap="YlGnBu")
    plt.savefig(filename)

# %% [markdown]
# 3. Define network

# %%
def poses_diff(x):
    H, W = x.get_shape()[1],x.get_shape()[2]
    x = tf.subtract(x[:,1:,...],x[:,:-1,...])
    x = tf.image.resize(x,size=[H,W]) 
    return x

def pose_motion(P,frame_l):
    P_diff_slow = Lambda(lambda x: poses_diff(x))(P)
    P_diff_slow = Reshape((frame_l,-1))(P_diff_slow)
    P_fast = Lambda(lambda x: x[:,::2,...])(P)
    P_diff_fast = Lambda(lambda x: poses_diff(x))(P_fast)
    P_diff_fast = Reshape((int(frame_l/2),-1))(P_diff_fast)
    return P_diff_slow,P_diff_fast
    
def c1D(x,filters,kernel):
    x = Conv1D(filters, kernel_size=kernel,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def block(x,filters):
    x = c1D(x,filters,3)
    x = c1D(x,filters,3)
    return x
    
def d1D(x,filters):
    x = Dense(filters,use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def build_FM(frame_l=32,joint_n=22,joint_d=2,feat_d=231,filters=16):   
    M = Input(shape=(frame_l,feat_d))
    P = Input(shape=(frame_l,joint_n,joint_d))
    
    diff_slow,diff_fast = pose_motion(P,frame_l)
    
    x = c1D(M,filters*2,1)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,3)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,1)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x_d_slow = c1D(diff_slow,filters*2,1)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,3)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,1)
    x_d_slow = MaxPool1D(2)(x_d_slow)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
        
    x_d_fast = c1D(diff_fast,filters*2,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,3) 
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,1) 
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
   
    x = concatenate([x,x_d_slow,x_d_fast])
    x = block(x,filters*2)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)
    
    x = block(x,filters*4)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*8)
    x = SpatialDropout1D(0.1)(x)
    
    return Model(inputs=[M,P],outputs=x)


def build_DD_Net(frame_l=32,joint_n=22,joint_d=3,feat_d=231,clc_num=14,filters=16):
    M = Input(name='M', shape=(frame_l,feat_d))  
    P = Input(name='P', shape=(frame_l,joint_n,joint_d)) 
    
    FM = build_FM(frame_l,joint_n,joint_d,feat_d,filters)
    
    x = FM([M,P])

    x = GlobalMaxPool1D()(x)
    
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = Dense(clc_num, activation='softmax')(x)
    
    ######################Self-supervised part
    model = Model(inputs=[M,P],outputs=x)
    return model

# %%
DD_Net = build_DD_Net(C.frame_l,C.joint_n,C.joint_d,C.feat_d,C.clc_coarse,C.filters)
DD_Net.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# M (InputLayer)                  [(None, 32, 231)]    0
# __________________________________________________________________________________________________
# P (InputLayer)                  [(None, 32, 22, 3)]  0
# __________________________________________________________________________________________________
# model (Functional)              (None, 4, 512)       1740160     M[0][0]
#                                                                  P[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 512)          0           model[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          65536       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128)          512         dense[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 128)          0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16384       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128)          512         dense_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 128)          0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 14)           1806        dropout_1[0][0]
# ==================================================================================================
# Total params: 1,824,910
# Trainable params: 1,819,278
# Non-trainable params: 5,632
# __________________________________________________________________________________________________

# %% [markdown]
# 4. Load dataset (download GT_train_1.pkl and  GT_test_1.pkl from github )

# %%
# !wget https://github.com/fandulu/DD-Net/archive/master.zip
# !unzip master.zip
# !rm master.zip
# Out:
# --2021-09-24 09:13:10--  https://github.com/fandulu/DD-Net/archive/master.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/fandulu/DD-Net/zip/master [following]
# --2021-09-24 09:13:10--  https://codeload.github.com/fandulu/DD-Net/zip/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [        <=>         ]  79.09M  12.9MB/s    in 6.1s
#
# 2021-09-24 09:13:16 (12.9 MB/s) - ‘master.zip’ saved [82934337]
#
# Archive:  master.zip
# f26a9994b0bafc41096fa269eab89c2757d71499
#    creating: DD-Net-master/
#   inflating: DD-Net-master/.gitignore
#    creating: DD-Net-master/JHMDB/
#   inflating: DD-Net-master/JHMDB/README.md
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_heavy.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_lite.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_middle.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_data_preprocessing.ipynb
#   inflating: DD-Net-master/JHMDB/utils.py
#    creating: DD-Net-master/JHMDB/weights/
#  extracting: DD-Net-master/JHMDB/weights/__init__.py
#   inflating: DD-Net-master/LICENSE
#   inflating: DD-Net-master/README.md
#    creating: DD-Net-master/SHREC/
#   inflating: DD-Net-master/SHREC/README.md
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_lite.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_data_preprocessing.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_lite.ipynb
#    creating: DD-Net-master/SHREC/images/
#   inflating: DD-Net-master/SHREC/images/SHREC_14.png
#   inflating: DD-Net-master/SHREC/images/SHREC_28.png
#   inflating: DD-Net-master/SHREC/utils.py
#    creating: DD-Net-master/SHREC/weights/
#  extracting: DD-Net-master/SHREC/weights/.gitkeep
#  extracting: DD-Net-master/SHREC/weights/__init__.py
#    creating: DD-Net-master/data/
#    creating: DD-Net-master/data/JHMDB/
#   inflating: DD-Net-master/data/JHMDB/GT_test_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_3.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_3.pkl
#   inflating: DD-Net-master/data/JHMDB/joint_positions.zip
#   inflating: DD-Net-master/data/JHMDB/splits.zip
#    creating: DD-Net-master/data/SHREC/
#  extracting: DD-Net-master/data/SHREC/__init__.py
#   inflating: DD-Net-master/data/SHREC/test.pickle
#   inflating: DD-Net-master/data/SHREC/test.pkl
#   inflating: DD-Net-master/data/SHREC/train.pickle
#   inflating: DD-Net-master/data/SHREC/train.pkl
#    creating: DD-Net-master/mics/
#  extracting: DD-Net-master/mics/__init__.py
#   inflating: DD-Net-master/mics/demo.png
#   inflating: DD-Net-master/mics/look.gif
#   inflating: DD-Net-master/mics/paper.png

# %% [markdown]
# 5. Running codes

# %%
Train = pickle.load(open("/content/DD-Net-master/data/SHREC/train.pkl", "rb"))
Test = pickle.load(open("/content/DD-Net-master/data/SHREC/test.pkl", "rb"))

X_0 = []
X_1 = []
Y = []
for i in tqdm(range(len(Train['pose']))): 
    p = np.copy(Train['pose'][i]).reshape([-1,22,3])
    p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)
    p = normlize_range(p)
    
    label = np.zeros(C.clc_coarse)
    label[Train['coarse_label'][i]-1] = 1   

    M = get_CG(p,C)

    X_0.append(M)
    X_1.append(p)
    Y.append(label)

X_0 = np.stack(X_0)  
X_1 = np.stack(X_1) 
Y = np.stack(Y)
# Out:
# 100%|██████████| 1960/1960 [00:16<00:00, 119.27it/s]

# %%
X_test_0 = []
X_test_1 = []
Y_test = []
for i in tqdm(range(len(Test['pose']))): 
    p = np.copy(Test['pose'][i]).reshape([-1,22,3])
    p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)
    p = normlize_range(p)
    
    label = np.zeros(C.clc_coarse)
    label[Test['coarse_label'][i]-1] = 1   

    M = get_CG(p,C)

    X_test_0.append(M)
    X_test_1.append(p)
    Y_test.append(label)

X_test_0 = np.stack(X_test_0) 
X_test_1 = np.stack(X_test_1)  
Y_test = np.stack(Y_test)
# Out:
# 100%|██████████| 840/840 [00:07<00:00, 118.12it/s]

# %%
X_test_0.shape
# Out:
# (840, 32, 231)

# %%
X_1.shape, X_0.shape
# Out:
# ((1960, 32, 22, 3), (1960, 32, 231))

# %%
X_1[0,0].shape
# Out:
# (22, 3)

# %%
import scipy
dist = scipy.spatial.distance_matrix(X_1[0,0], X_1[0,0])

# %%
dist.shape
# Out:
# (22, 22)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.matshow(dist);
plt.colorbar()
plt.show()

# %%
from sklearn.metrics.pairwise import euclidean_distances

# %%
plt.matshow(euclidean_distances(X_1[0,0,:, :2], X_1[0,0, :, :2]));
plt.colorbar()
plt.show()

# %%
for i, d in enumerate(dist):
  dist[i,i:] = 0 
plt.matshow(dist);
plt.colorbar()
plt.show()

# %%
vector = []
for i, d in enumerate(dist):
  vector.extend(dist.T[i,i+1:])

# %%
X_0[0,0] == vector
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
plt.scatter(X_1[100,0, :, 0], X_1[100,0, :, 1])
plt.show()

# %%
plt.plot(X_1[100,0, :, 0], X_1[100,0, :, 1])
plt.show()

# %%
np.insert(X_1[100,0, :, :], 1, [0,0,0], axis=0).shape
# Out:
# (23, 3)

# %%
X_1[100,0, 0, :], X_1[100,0, 10, :], X_1[100,0, 14, :]
# Out:
# (array([ 0.01374802, -0.06619064,  0.00424293]),
#  array([0.0226393 , 0.00555488, 0.01614893]),
#  array([0.03994667, 0.00537176, 0.01211092]))

# %%
c1_x = (X_1[100,0, 0, 0] + X_1[100,0, 10, 0])/2
c1_y = (X_1[100,0, 0, 1] + X_1[100,0, 10, 1])/2
c1_z = (X_1[100,0, 0, 2] + X_1[100,0, 10, 2])/2

c2_x = (X_1[100,0, 0, 0] + X_1[100,0, 14, 0])/2
c2_y = (X_1[100,0, 0, 1] + X_1[100,0, 14, 1])/2
c2_z = (X_1[100,0, 0, 2] + X_1[100,0, 14, 2])/2

c_x = (c1_x + c2_x)/2
c_y = (c1_y + c2_y)/2
c_z = (c1_z + c2_z)/2

# %%
c_x, c_y, c_z
# Out:
# (0.02252050010826101, -0.0017352694730189688, 0.018521636470474973)

# %%
plt.plot(X_1[100,0, :, 0], X_1[100,0, :, 1])
plt.plot(X_1[100,0, 0, 0], X_1[100,0, 0, 1], 'go')
plt.plot(X_1[100,0, 10, 0], X_1[100,0, 10, 1], 'go')
plt.plot(X_1[100,0, 14, 0], X_1[100,0, 14, 1], 'go')
plt.plot(c1_x,c1_y, 'go')
plt.plot(c2_x, c2_y, 'go')
plt.plot(c_x, c_y, 'r+')
plt.show()

# %%
tf.keras.optimizers.Adam(learning_rate=0.1)

# %%
# it may takes several times to reach the reported performance
lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=tf.keras.optimizers.Adam(learning_rate=lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
            batch_size=len(Y),
            epochs=1000,
            verbose=True,
            shuffle=True,
            callbacks=[lrScheduler],
            validation_data=([X_test_0,X_test_1],Y_test)      
            )
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 42s 42s/step - loss: 3.3151 - accuracy: 0.0699 - val_loss: 2.6389 - val_accuracy: 0.0679
# Epoch 2/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 3.2394 - accuracy: 0.0684 - val_loss: 2.6387 - val_accuracy: 0.0679
# Epoch 3/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 3.1493 - accuracy: 0.0898 - val_loss: 2.6388 - val_accuracy: 0.0679
# Epoch 4/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 3.0607 - accuracy: 0.0878 - val_loss: 2.6388 - val_accuracy: 0.0440
# Epoch 5/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 3.0360 - accuracy: 0.0923 - val_loss: 2.6388 - val_accuracy: 0.0690
# Epoch 6/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 2.9341 - accuracy: 0.1224 - val_loss: 2.6390 - val_accuracy: 0.0690
# Epoch 7/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 2.9451 - accuracy: 0.1015 - val_loss: 2.6391 - val_accuracy: 0.0690
# Epoch 8/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 2.8465 - accuracy: 0.1291 - val_loss: 2.6393 - val_accuracy: 0.0690
# Epoch 9/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 2.8150 - accuracy: 0.1250 - val_loss: 2.6395 - val_accuracy: 0.0690
# Epoch 10/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 2.7452 - accuracy: 0.1342 - val_loss: 2.6397 - val_accuracy: 0.0690
# Epoch 11/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 2.7703 - accuracy: 0.1357 - val_loss: 2.6400 - val_accuracy: 0.0690
# Epoch 12/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 2.7381 - accuracy: 0.1342 - val_loss: 2.6403 - val_accuracy: 0.0690
# Epoch 13/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 2.6453 - accuracy: 0.1597 - val_loss: 2.6407 - val_accuracy: 0.0690
# Epoch 14/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 2.6326 - accuracy: 0.1602 - val_loss: 2.6411 - val_accuracy: 0.0690
# Epoch 15/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 2.5782 - accuracy: 0.1781 - val_loss: 2.6416 - val_accuracy: 0.0655
# Epoch 16/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 2.5853 - accuracy: 0.1709 - val_loss: 2.6422 - val_accuracy: 0.0607
# Epoch 17/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 2.4953 - accuracy: 0.1852 - val_loss: 2.6428 - val_accuracy: 0.0607
# Epoch 18/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 2.5071 - accuracy: 0.1893 - val_loss: 2.6434 - val_accuracy: 0.0607
# Epoch 19/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 2.4556 - accuracy: 0.1913 - val_loss: 2.6440 - val_accuracy: 0.0607
# Epoch 20/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 2.4362 - accuracy: 0.2112 - val_loss: 2.6447 - val_accuracy: 0.0607
# Epoch 21/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 2.3592 - accuracy: 0.2316 - val_loss: 2.6454 - val_accuracy: 0.0607
# Epoch 22/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 2.4017 - accuracy: 0.2163 - val_loss: 2.6462 - val_accuracy: 0.0607
# Epoch 23/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 2.3596 - accuracy: 0.2184 - val_loss: 2.6469 - val_accuracy: 0.0607
# Epoch 24/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 2.3096 - accuracy: 0.2388 - val_loss: 2.6476 - val_accuracy: 0.0607
# Epoch 25/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 2.2695 - accuracy: 0.2653 - val_loss: 2.6484 - val_accuracy: 0.0607
# Epoch 26/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 2.2434 - accuracy: 0.2806 - val_loss: 2.6491 - val_accuracy: 0.0607
# Epoch 27/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 2.2220 - accuracy: 0.2770 - val_loss: 2.6499 - val_accuracy: 0.0607
# Epoch 28/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 2.1808 - accuracy: 0.2827 - val_loss: 2.6507 - val_accuracy: 0.0607
# Epoch 29/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 2.1617 - accuracy: 0.3020 - val_loss: 2.6514 - val_accuracy: 0.0607
# Epoch 30/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 2.1499 - accuracy: 0.3026 - val_loss: 2.6522 - val_accuracy: 0.0607
# Epoch 31/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 2.1612 - accuracy: 0.2944 - val_loss: 2.6530 - val_accuracy: 0.0607
# Epoch 32/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 2.0981 - accuracy: 0.3250 - val_loss: 2.6538 - val_accuracy: 0.0607
# Epoch 33/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 2.0571 - accuracy: 0.3301 - val_loss: 2.6545 - val_accuracy: 0.0607
# Epoch 34/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 2.0125 - accuracy: 0.3439 - val_loss: 2.6553 - val_accuracy: 0.0607
# Epoch 35/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 2.0320 - accuracy: 0.3398 - val_loss: 2.6561 - val_accuracy: 0.0607
# Epoch 36/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 1.9630 - accuracy: 0.3628 - val_loss: 2.6569 - val_accuracy: 0.0607
# Epoch 37/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 1.9179 - accuracy: 0.3699 - val_loss: 2.6576 - val_accuracy: 0.0607
# Epoch 38/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 1.9215 - accuracy: 0.3821 - val_loss: 2.6584 - val_accuracy: 0.0607
# Epoch 39/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 1.9062 - accuracy: 0.3837 - val_loss: 2.6592 - val_accuracy: 0.0607
# Epoch 40/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 1.8723 - accuracy: 0.4051 - val_loss: 2.6600 - val_accuracy: 0.0607
# Epoch 41/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 1.8408 - accuracy: 0.4066 - val_loss: 2.6608 - val_accuracy: 0.0607
# Epoch 42/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 1.8180 - accuracy: 0.4153 - val_loss: 2.6616 - val_accuracy: 0.0607
# Epoch 43/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 1.7782 - accuracy: 0.4255 - val_loss: 2.6624 - val_accuracy: 0.0607
# Epoch 44/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 1.7486 - accuracy: 0.4556 - val_loss: 2.6632 - val_accuracy: 0.0607
# Epoch 45/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 1.7251 - accuracy: 0.4577 - val_loss: 2.6641 - val_accuracy: 0.0607
# Epoch 46/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 1.7494 - accuracy: 0.4459 - val_loss: 2.6650 - val_accuracy: 0.0607
# Epoch 47/1000
# 1/1 [==============================] - 0s 352ms/step - loss: 1.6855 - accuracy: 0.4709 - val_loss: 2.6660 - val_accuracy: 0.0607
# Epoch 48/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 1.6796 - accuracy: 0.4684 - val_loss: 2.6670 - val_accuracy: 0.0607
# Epoch 49/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 1.6492 - accuracy: 0.4969 - val_loss: 2.6680 - val_accuracy: 0.0607
# Epoch 50/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 1.6264 - accuracy: 0.4990 - val_loss: 2.6690 - val_accuracy: 0.0607
# Epoch 51/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 1.6131 - accuracy: 0.4939 - val_loss: 2.6700 - val_accuracy: 0.0607
# Epoch 52/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 1.5695 - accuracy: 0.5209 - val_loss: 2.6711 - val_accuracy: 0.0607
# Epoch 53/1000
# 1/1 [==============================] - 0s 349ms/step - loss: 1.5534 - accuracy: 0.5286 - val_loss: 2.6724 - val_accuracy: 0.0607
# Epoch 54/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 1.5321 - accuracy: 0.5286 - val_loss: 2.6736 - val_accuracy: 0.0607
# Epoch 55/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 1.5413 - accuracy: 0.5403 - val_loss: 2.6749 - val_accuracy: 0.0607
# Epoch 56/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 1.4867 - accuracy: 0.5510 - val_loss: 2.6761 - val_accuracy: 0.0607
# Epoch 57/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 1.4842 - accuracy: 0.5347 - val_loss: 2.6775 - val_accuracy: 0.0607
# Epoch 58/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 1.4961 - accuracy: 0.5393 - val_loss: 2.6790 - val_accuracy: 0.0607
# Epoch 59/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 1.4485 - accuracy: 0.5587 - val_loss: 2.6804 - val_accuracy: 0.0607
# Epoch 60/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 1.4304 - accuracy: 0.5781 - val_loss: 2.6820 - val_accuracy: 0.0607
# Epoch 61/1000
# 1/1 [==============================] - 0s 352ms/step - loss: 1.4197 - accuracy: 0.5638 - val_loss: 2.6836 - val_accuracy: 0.0607
# Epoch 62/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 1.3810 - accuracy: 0.5893 - val_loss: 2.6852 - val_accuracy: 0.0607
# Epoch 63/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 1.3615 - accuracy: 0.5913 - val_loss: 2.6868 - val_accuracy: 0.0607
# Epoch 64/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 1.3721 - accuracy: 0.5883 - val_loss: 2.6884 - val_accuracy: 0.0607
# Epoch 65/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 1.3026 - accuracy: 0.6173 - val_loss: 2.6901 - val_accuracy: 0.0607
# Epoch 66/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 1.3323 - accuracy: 0.6128 - val_loss: 2.6919 - val_accuracy: 0.0607
# Epoch 67/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 1.2819 - accuracy: 0.6403 - val_loss: 2.6936 - val_accuracy: 0.0607
# Epoch 68/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 1.2828 - accuracy: 0.6194 - val_loss: 2.6952 - val_accuracy: 0.0607
# Epoch 69/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 1.2537 - accuracy: 0.6332 - val_loss: 2.6968 - val_accuracy: 0.0607
# Epoch 70/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 1.2499 - accuracy: 0.6291 - val_loss: 2.6984 - val_accuracy: 0.0607
# Epoch 71/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 1.2470 - accuracy: 0.6398 - val_loss: 2.7000 - val_accuracy: 0.0607
# Epoch 72/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 1.2232 - accuracy: 0.6500 - val_loss: 2.7017 - val_accuracy: 0.0607
# Epoch 73/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 1.2026 - accuracy: 0.6633 - val_loss: 2.7033 - val_accuracy: 0.0607
# Epoch 74/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 1.2056 - accuracy: 0.6592 - val_loss: 2.7050 - val_accuracy: 0.0607
# Epoch 75/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 1.1875 - accuracy: 0.6719 - val_loss: 2.7068 - val_accuracy: 0.0607
# Epoch 76/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 1.2012 - accuracy: 0.6658 - val_loss: 2.7087 - val_accuracy: 0.0607
# Epoch 77/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 1.1558 - accuracy: 0.6750 - val_loss: 2.7106 - val_accuracy: 0.0607
# Epoch 78/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 1.1458 - accuracy: 0.6689 - val_loss: 2.7124 - val_accuracy: 0.0607
# Epoch 79/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 1.1640 - accuracy: 0.6704 - val_loss: 2.7142 - val_accuracy: 0.0607
# Epoch 80/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 1.1246 - accuracy: 0.6954 - val_loss: 2.7160 - val_accuracy: 0.0607
# Epoch 81/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 1.1284 - accuracy: 0.6923 - val_loss: 2.7179 - val_accuracy: 0.0607
# Epoch 82/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 1.1376 - accuracy: 0.6781 - val_loss: 2.7196 - val_accuracy: 0.0607
# Epoch 83/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 1.0865 - accuracy: 0.6918 - val_loss: 2.7213 - val_accuracy: 0.0607
# Epoch 84/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 1.0949 - accuracy: 0.6934 - val_loss: 2.7230 - val_accuracy: 0.0607
# Epoch 85/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 1.0614 - accuracy: 0.7015 - val_loss: 2.7248 - val_accuracy: 0.0607
# Epoch 86/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 1.0714 - accuracy: 0.6913 - val_loss: 2.7263 - val_accuracy: 0.0607
# Epoch 87/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 1.0484 - accuracy: 0.7209 - val_loss: 2.7277 - val_accuracy: 0.0607
# Epoch 88/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 1.0175 - accuracy: 0.7219 - val_loss: 2.7291 - val_accuracy: 0.0607
# Epoch 89/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 1.0253 - accuracy: 0.7270 - val_loss: 2.7304 - val_accuracy: 0.0607
# Epoch 90/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 1.0019 - accuracy: 0.7230 - val_loss: 2.7316 - val_accuracy: 0.0607
# Epoch 91/1000
# 1/1 [==============================] - 0s 351ms/step - loss: 1.0175 - accuracy: 0.7184 - val_loss: 2.7327 - val_accuracy: 0.0607
# Epoch 92/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.9892 - accuracy: 0.7301 - val_loss: 2.7338 - val_accuracy: 0.0607
# Epoch 93/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.9710 - accuracy: 0.7505 - val_loss: 2.7348 - val_accuracy: 0.0607
# Epoch 94/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.9557 - accuracy: 0.7490 - val_loss: 2.7357 - val_accuracy: 0.0607
# Epoch 95/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.9600 - accuracy: 0.7510 - val_loss: 2.7365 - val_accuracy: 0.0607
# Epoch 96/1000
# 1/1 [==============================] - 0s 352ms/step - loss: 0.9647 - accuracy: 0.7306 - val_loss: 2.7373 - val_accuracy: 0.0607
# Epoch 97/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.9609 - accuracy: 0.7418 - val_loss: 2.7380 - val_accuracy: 0.0607
# Epoch 98/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.9371 - accuracy: 0.7459 - val_loss: 2.7388 - val_accuracy: 0.0607
# Epoch 99/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.9380 - accuracy: 0.7413 - val_loss: 2.7395 - val_accuracy: 0.0607
# Epoch 100/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.9234 - accuracy: 0.7577 - val_loss: 2.7402 - val_accuracy: 0.0619
# Epoch 101/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.9190 - accuracy: 0.7577 - val_loss: 2.7408 - val_accuracy: 0.0619
# Epoch 102/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.9080 - accuracy: 0.7612 - val_loss: 2.7413 - val_accuracy: 0.0619
# Epoch 103/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.8995 - accuracy: 0.7577 - val_loss: 2.7416 - val_accuracy: 0.0631
# Epoch 104/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.8817 - accuracy: 0.7612 - val_loss: 2.7421 - val_accuracy: 0.0631
# Epoch 105/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.8855 - accuracy: 0.7628 - val_loss: 2.7426 - val_accuracy: 0.0631
# Epoch 106/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.8810 - accuracy: 0.7709 - val_loss: 2.7428 - val_accuracy: 0.0667
# Epoch 107/1000
# 1/1 [==============================] - 0s 352ms/step - loss: 0.8700 - accuracy: 0.7704 - val_loss: 2.7433 - val_accuracy: 0.0667
# Epoch 108/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.8500 - accuracy: 0.7791 - val_loss: 2.7439 - val_accuracy: 0.0690
# Epoch 109/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.8488 - accuracy: 0.7791 - val_loss: 2.7444 - val_accuracy: 0.0750
# Epoch 110/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.8251 - accuracy: 0.7918 - val_loss: 2.7451 - val_accuracy: 0.0786
# Epoch 111/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.8409 - accuracy: 0.7918 - val_loss: 2.7458 - val_accuracy: 0.0821
# Epoch 112/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.8249 - accuracy: 0.7832 - val_loss: 2.7463 - val_accuracy: 0.0857
# Epoch 113/1000
# 1/1 [==============================] - 0s 351ms/step - loss: 0.8140 - accuracy: 0.7959 - val_loss: 2.7470 - val_accuracy: 0.0881
# Epoch 114/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.8148 - accuracy: 0.7949 - val_loss: 2.7478 - val_accuracy: 0.0940
# Epoch 115/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.8065 - accuracy: 0.8056 - val_loss: 2.7487 - val_accuracy: 0.0952
# Epoch 116/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.7942 - accuracy: 0.8107 - val_loss: 2.7494 - val_accuracy: 0.0988
# Epoch 117/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.7953 - accuracy: 0.7969 - val_loss: 2.7500 - val_accuracy: 0.1000
# Epoch 118/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.7821 - accuracy: 0.8020 - val_loss: 2.7507 - val_accuracy: 0.1012
# Epoch 119/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.7738 - accuracy: 0.8087 - val_loss: 2.7514 - val_accuracy: 0.1036
# Epoch 120/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.7526 - accuracy: 0.8122 - val_loss: 2.7520 - val_accuracy: 0.1036
# Epoch 121/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.7747 - accuracy: 0.8000 - val_loss: 2.7527 - val_accuracy: 0.1036
# Epoch 122/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.7384 - accuracy: 0.8245 - val_loss: 2.7533 - val_accuracy: 0.1048
# Epoch 123/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.7375 - accuracy: 0.8122 - val_loss: 2.7536 - val_accuracy: 0.1071
# Epoch 124/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.7344 - accuracy: 0.8158 - val_loss: 2.7538 - val_accuracy: 0.1071
# Epoch 125/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.7335 - accuracy: 0.8133 - val_loss: 2.7536 - val_accuracy: 0.1083
# Epoch 126/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.7154 - accuracy: 0.8230 - val_loss: 2.7535 - val_accuracy: 0.1083
# Epoch 127/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.7243 - accuracy: 0.8235 - val_loss: 2.7530 - val_accuracy: 0.1083
# Epoch 128/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.7220 - accuracy: 0.8286 - val_loss: 2.7523 - val_accuracy: 0.1107
# Epoch 129/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.7346 - accuracy: 0.8235 - val_loss: 2.7510 - val_accuracy: 0.1143
# Epoch 130/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.7145 - accuracy: 0.8291 - val_loss: 2.7500 - val_accuracy: 0.1143
# Epoch 131/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.7084 - accuracy: 0.8332 - val_loss: 2.7485 - val_accuracy: 0.1155
# Epoch 132/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.7105 - accuracy: 0.8296 - val_loss: 2.7473 - val_accuracy: 0.1155
# Epoch 133/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.6864 - accuracy: 0.8342 - val_loss: 2.7463 - val_accuracy: 0.1155
# Epoch 134/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.6727 - accuracy: 0.8362 - val_loss: 2.7456 - val_accuracy: 0.1167
# Epoch 135/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.7088 - accuracy: 0.8337 - val_loss: 2.7452 - val_accuracy: 0.1167
# Epoch 136/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.6887 - accuracy: 0.8332 - val_loss: 2.7449 - val_accuracy: 0.1167
# Epoch 137/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.6907 - accuracy: 0.8398 - val_loss: 2.7448 - val_accuracy: 0.1190
# Epoch 138/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.6745 - accuracy: 0.8372 - val_loss: 2.7447 - val_accuracy: 0.1190
# Epoch 139/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.6555 - accuracy: 0.8464 - val_loss: 2.7449 - val_accuracy: 0.1190
# Epoch 140/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.6577 - accuracy: 0.8464 - val_loss: 2.7451 - val_accuracy: 0.1190
# Epoch 141/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.6393 - accuracy: 0.8571 - val_loss: 2.7455 - val_accuracy: 0.1202
# Epoch 142/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.6424 - accuracy: 0.8485 - val_loss: 2.7462 - val_accuracy: 0.1202
# Epoch 143/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.6268 - accuracy: 0.8592 - val_loss: 2.7464 - val_accuracy: 0.1202
# Epoch 144/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.6319 - accuracy: 0.8500 - val_loss: 2.7465 - val_accuracy: 0.1202
# Epoch 145/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.6189 - accuracy: 0.8597 - val_loss: 2.7459 - val_accuracy: 0.1202
# Epoch 146/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.6376 - accuracy: 0.8464 - val_loss: 2.7452 - val_accuracy: 0.1202
# Epoch 147/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.6012 - accuracy: 0.8556 - val_loss: 2.7441 - val_accuracy: 0.1202
# Epoch 148/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.6078 - accuracy: 0.8673 - val_loss: 2.7431 - val_accuracy: 0.1202
# Epoch 149/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.5940 - accuracy: 0.8556 - val_loss: 2.7426 - val_accuracy: 0.1202
# Epoch 150/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.6122 - accuracy: 0.8617 - val_loss: 2.7418 - val_accuracy: 0.1202
# Epoch 151/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.6010 - accuracy: 0.8551 - val_loss: 2.7412 - val_accuracy: 0.1202
# Epoch 152/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.5755 - accuracy: 0.8724 - val_loss: 2.7403 - val_accuracy: 0.1202
# Epoch 153/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 0.5875 - accuracy: 0.8653 - val_loss: 2.7396 - val_accuracy: 0.1202
# Epoch 154/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.5866 - accuracy: 0.8658 - val_loss: 2.7388 - val_accuracy: 0.1202
# Epoch 155/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.5906 - accuracy: 0.8643 - val_loss: 2.7374 - val_accuracy: 0.1202
# Epoch 156/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.5773 - accuracy: 0.8689 - val_loss: 2.7364 - val_accuracy: 0.1202
# Epoch 157/1000
# 1/1 [==============================] - 0s 351ms/step - loss: 0.5759 - accuracy: 0.8760 - val_loss: 2.7360 - val_accuracy: 0.1202
# Epoch 158/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.5831 - accuracy: 0.8735 - val_loss: 2.7355 - val_accuracy: 0.1202
# Epoch 159/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.5909 - accuracy: 0.8612 - val_loss: 2.7346 - val_accuracy: 0.1202
# Epoch 160/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.5634 - accuracy: 0.8735 - val_loss: 2.7337 - val_accuracy: 0.1202
# Epoch 161/1000
# 1/1 [==============================] - 0s 349ms/step - loss: 0.5643 - accuracy: 0.8781 - val_loss: 2.7326 - val_accuracy: 0.1202
# Epoch 162/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.5606 - accuracy: 0.8791 - val_loss: 2.7315 - val_accuracy: 0.1202
# Epoch 163/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.5701 - accuracy: 0.8719 - val_loss: 2.7302 - val_accuracy: 0.1202
# Epoch 164/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.5597 - accuracy: 0.8765 - val_loss: 2.7287 - val_accuracy: 0.1202
# Epoch 165/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 0.5512 - accuracy: 0.8755 - val_loss: 2.7272 - val_accuracy: 0.1202
# Epoch 166/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.5851 - accuracy: 0.8684 - val_loss: 2.7257 - val_accuracy: 0.1214
# Epoch 167/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.5539 - accuracy: 0.8684 - val_loss: 2.7242 - val_accuracy: 0.1214
# Epoch 168/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.5550 - accuracy: 0.8745 - val_loss: 2.7228 - val_accuracy: 0.1214
# Epoch 169/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.5476 - accuracy: 0.8862 - val_loss: 2.7215 - val_accuracy: 0.1214
# Epoch 170/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.5444 - accuracy: 0.8811 - val_loss: 2.7200 - val_accuracy: 0.1214
# Epoch 171/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.5470 - accuracy: 0.8796 - val_loss: 2.7183 - val_accuracy: 0.1214
# Epoch 172/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.5419 - accuracy: 0.8801 - val_loss: 2.7163 - val_accuracy: 0.1214
# Epoch 173/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.5228 - accuracy: 0.8878 - val_loss: 2.7146 - val_accuracy: 0.1214
# Epoch 174/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.5369 - accuracy: 0.8867 - val_loss: 2.7127 - val_accuracy: 0.1226
# Epoch 175/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.5298 - accuracy: 0.8867 - val_loss: 2.7107 - val_accuracy: 0.1226
# Epoch 176/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.5218 - accuracy: 0.8903 - val_loss: 2.7090 - val_accuracy: 0.1226
# Epoch 177/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.5395 - accuracy: 0.8857 - val_loss: 2.7072 - val_accuracy: 0.1238
# Epoch 178/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.5443 - accuracy: 0.8806 - val_loss: 2.7053 - val_accuracy: 0.1238
# Epoch 179/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.5375 - accuracy: 0.8883 - val_loss: 2.7033 - val_accuracy: 0.1238
# Epoch 180/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.5422 - accuracy: 0.8816 - val_loss: 2.7015 - val_accuracy: 0.1238
# Epoch 181/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.5297 - accuracy: 0.8903 - val_loss: 2.7001 - val_accuracy: 0.1238
# Epoch 182/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.5239 - accuracy: 0.8893 - val_loss: 2.6983 - val_accuracy: 0.1238
# Epoch 183/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.5033 - accuracy: 0.8954 - val_loss: 2.6966 - val_accuracy: 0.1238
# Epoch 184/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.5272 - accuracy: 0.8872 - val_loss: 2.6950 - val_accuracy: 0.1238
# Epoch 185/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.5139 - accuracy: 0.8923 - val_loss: 2.6935 - val_accuracy: 0.1238
# Epoch 186/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.5051 - accuracy: 0.8878 - val_loss: 2.6919 - val_accuracy: 0.1238
# Epoch 187/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.5236 - accuracy: 0.8857 - val_loss: 2.6901 - val_accuracy: 0.1238
# Epoch 188/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.5256 - accuracy: 0.8867 - val_loss: 2.6883 - val_accuracy: 0.1238
# Epoch 189/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.5200 - accuracy: 0.8832 - val_loss: 2.6866 - val_accuracy: 0.1238
# Epoch 190/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.5305 - accuracy: 0.8847 - val_loss: 2.6848 - val_accuracy: 0.1238
# Epoch 191/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.5265 - accuracy: 0.8872 - val_loss: 2.6830 - val_accuracy: 0.1238
# Epoch 192/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.5168 - accuracy: 0.8862 - val_loss: 2.6811 - val_accuracy: 0.1238
# Epoch 193/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.5168 - accuracy: 0.8878 - val_loss: 2.6792 - val_accuracy: 0.1238
# Epoch 194/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 0.5133 - accuracy: 0.8893 - val_loss: 2.6770 - val_accuracy: 0.1250
# Epoch 195/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.5154 - accuracy: 0.8959 - val_loss: 2.6747 - val_accuracy: 0.1250
# Epoch 196/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.5012 - accuracy: 0.8974 - val_loss: 2.6724 - val_accuracy: 0.1250
# Epoch 197/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.5043 - accuracy: 0.8903 - val_loss: 2.6701 - val_accuracy: 0.1250
# Epoch 198/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.4942 - accuracy: 0.8974 - val_loss: 2.6679 - val_accuracy: 0.1250
# Epoch 199/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.5098 - accuracy: 0.8985 - val_loss: 2.6657 - val_accuracy: 0.1250
# Epoch 200/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.4975 - accuracy: 0.8990 - val_loss: 2.6636 - val_accuracy: 0.1250
# Epoch 201/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 0.5020 - accuracy: 0.8944 - val_loss: 2.6613 - val_accuracy: 0.1250
# Epoch 202/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.5096 - accuracy: 0.8969 - val_loss: 2.6592 - val_accuracy: 0.1250
# Epoch 203/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.5076 - accuracy: 0.8913 - val_loss: 2.6568 - val_accuracy: 0.1250
# Epoch 204/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.4947 - accuracy: 0.9005 - val_loss: 2.6546 - val_accuracy: 0.1250
# Epoch 205/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.5118 - accuracy: 0.8847 - val_loss: 2.6524 - val_accuracy: 0.1250
# Epoch 206/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.5136 - accuracy: 0.8878 - val_loss: 2.6501 - val_accuracy: 0.1250
# Epoch 207/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.5083 - accuracy: 0.8918 - val_loss: 2.6479 - val_accuracy: 0.1250
# Epoch 208/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.5056 - accuracy: 0.8974 - val_loss: 2.6458 - val_accuracy: 0.1250
# Epoch 209/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.4858 - accuracy: 0.9036 - val_loss: 2.6435 - val_accuracy: 0.1250
# Epoch 210/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.5094 - accuracy: 0.8852 - val_loss: 2.6411 - val_accuracy: 0.1250
# Epoch 211/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.4996 - accuracy: 0.9015 - val_loss: 2.6389 - val_accuracy: 0.1262
# Epoch 212/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.5028 - accuracy: 0.8949 - val_loss: 2.6366 - val_accuracy: 0.1262
# Epoch 213/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4892 - accuracy: 0.9020 - val_loss: 2.6342 - val_accuracy: 0.1262
# Epoch 214/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.5192 - accuracy: 0.8862 - val_loss: 2.6316 - val_accuracy: 0.1262
# Epoch 215/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.5032 - accuracy: 0.8898 - val_loss: 2.6291 - val_accuracy: 0.1274
# Epoch 216/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.5019 - accuracy: 0.8974 - val_loss: 2.6267 - val_accuracy: 0.1274
# Epoch 217/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.4806 - accuracy: 0.9026 - val_loss: 2.6243 - val_accuracy: 0.1274
# Epoch 218/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.5112 - accuracy: 0.8990 - val_loss: 2.6216 - val_accuracy: 0.1286
# Epoch 219/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.5146 - accuracy: 0.8934 - val_loss: 2.6189 - val_accuracy: 0.1286
# Epoch 220/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.5041 - accuracy: 0.8995 - val_loss: 2.6164 - val_accuracy: 0.1286
# Epoch 221/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.5152 - accuracy: 0.8816 - val_loss: 2.6137 - val_accuracy: 0.1298
# Epoch 222/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.5113 - accuracy: 0.8893 - val_loss: 2.6110 - val_accuracy: 0.1298
# Epoch 223/1000
# 1/1 [==============================] - 0s 350ms/step - loss: 0.5051 - accuracy: 0.8954 - val_loss: 2.6083 - val_accuracy: 0.1298
# Epoch 224/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.5023 - accuracy: 0.8893 - val_loss: 2.6056 - val_accuracy: 0.1298
# Epoch 225/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.4957 - accuracy: 0.8974 - val_loss: 2.6028 - val_accuracy: 0.1310
# Epoch 226/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.5230 - accuracy: 0.8939 - val_loss: 2.6000 - val_accuracy: 0.1310
# Epoch 227/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.5129 - accuracy: 0.8959 - val_loss: 2.5970 - val_accuracy: 0.1310
# Epoch 228/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.4916 - accuracy: 0.9051 - val_loss: 2.5941 - val_accuracy: 0.1310
# Epoch 229/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.4863 - accuracy: 0.9102 - val_loss: 2.5911 - val_accuracy: 0.1321
# Epoch 230/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.5047 - accuracy: 0.9036 - val_loss: 2.5881 - val_accuracy: 0.1357
# Epoch 231/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.4853 - accuracy: 0.8964 - val_loss: 2.5852 - val_accuracy: 0.1369
# Epoch 232/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.5027 - accuracy: 0.9020 - val_loss: 2.5820 - val_accuracy: 0.1369
# Epoch 233/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.5004 - accuracy: 0.8990 - val_loss: 2.5791 - val_accuracy: 0.1369
# Epoch 234/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.5192 - accuracy: 0.8878 - val_loss: 2.5760 - val_accuracy: 0.1369
# Epoch 235/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.5132 - accuracy: 0.8949 - val_loss: 2.5728 - val_accuracy: 0.1381
# Epoch 236/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.5026 - accuracy: 0.8842 - val_loss: 2.5698 - val_accuracy: 0.1381
# Epoch 237/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.5113 - accuracy: 0.8857 - val_loss: 2.5665 - val_accuracy: 0.1393
# Epoch 238/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.5130 - accuracy: 0.8857 - val_loss: 2.5634 - val_accuracy: 0.1393
# Epoch 239/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.4926 - accuracy: 0.8990 - val_loss: 2.5601 - val_accuracy: 0.1405
# Epoch 240/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.5008 - accuracy: 0.8949 - val_loss: 2.5567 - val_accuracy: 0.1417
# Epoch 241/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.5051 - accuracy: 0.8985 - val_loss: 2.5533 - val_accuracy: 0.1429
# Epoch 242/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.5089 - accuracy: 0.8969 - val_loss: 2.5499 - val_accuracy: 0.1440
# Epoch 243/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.5271 - accuracy: 0.8893 - val_loss: 2.5465 - val_accuracy: 0.1440
# Epoch 244/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4942 - accuracy: 0.9051 - val_loss: 2.5429 - val_accuracy: 0.1452
# Epoch 245/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.4892 - accuracy: 0.9000 - val_loss: 2.5395 - val_accuracy: 0.1452
# Epoch 246/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.5124 - accuracy: 0.8949 - val_loss: 2.5360 - val_accuracy: 0.1452
# Epoch 247/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.4936 - accuracy: 0.8985 - val_loss: 2.5324 - val_accuracy: 0.1464
# Epoch 248/1000
# 1/1 [==============================] - 0s 347ms/step - loss: 0.4955 - accuracy: 0.8980 - val_loss: 2.5289 - val_accuracy: 0.1488
# Epoch 249/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.5000 - accuracy: 0.8893 - val_loss: 2.5253 - val_accuracy: 0.1524
# Epoch 250/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.5146 - accuracy: 0.8969 - val_loss: 2.5215 - val_accuracy: 0.1536
# Epoch 251/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.5006 - accuracy: 0.8949 - val_loss: 2.5178 - val_accuracy: 0.1536
# Epoch 252/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.5252 - accuracy: 0.8821 - val_loss: 2.5139 - val_accuracy: 0.1536
# Epoch 253/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.5047 - accuracy: 0.8954 - val_loss: 2.5102 - val_accuracy: 0.1536
# Epoch 254/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.5045 - accuracy: 0.8883 - val_loss: 2.5062 - val_accuracy: 0.1548
# Epoch 255/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.4917 - accuracy: 0.9036 - val_loss: 2.5024 - val_accuracy: 0.1560
# Epoch 256/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.5040 - accuracy: 0.8913 - val_loss: 2.4983 - val_accuracy: 0.1560
# Epoch 257/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4969 - accuracy: 0.8954 - val_loss: 2.4942 - val_accuracy: 0.1571
# Epoch 258/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.5001 - accuracy: 0.8949 - val_loss: 2.4903 - val_accuracy: 0.1583
# Epoch 259/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.4850 - accuracy: 0.9020 - val_loss: 2.4861 - val_accuracy: 0.1583
# Epoch 260/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.5137 - accuracy: 0.8918 - val_loss: 2.4819 - val_accuracy: 0.1607
# Epoch 261/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.5069 - accuracy: 0.8954 - val_loss: 2.4777 - val_accuracy: 0.1607
# Epoch 262/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.5071 - accuracy: 0.8980 - val_loss: 2.4734 - val_accuracy: 0.1619
# Epoch 263/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.4944 - accuracy: 0.9020 - val_loss: 2.4693 - val_accuracy: 0.1619
# Epoch 264/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.4977 - accuracy: 0.9041 - val_loss: 2.4651 - val_accuracy: 0.1619
# Epoch 265/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.4922 - accuracy: 0.8974 - val_loss: 2.4609 - val_accuracy: 0.1643
# Epoch 266/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4843 - accuracy: 0.8969 - val_loss: 2.4566 - val_accuracy: 0.1655
# Epoch 267/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.4840 - accuracy: 0.9061 - val_loss: 2.4523 - val_accuracy: 0.1655
# Epoch 268/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.4955 - accuracy: 0.8908 - val_loss: 2.4479 - val_accuracy: 0.1667
# Epoch 269/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.5038 - accuracy: 0.8903 - val_loss: 2.4435 - val_accuracy: 0.1667
# Epoch 270/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4839 - accuracy: 0.9056 - val_loss: 2.4391 - val_accuracy: 0.1667
# Epoch 271/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.4919 - accuracy: 0.8883 - val_loss: 2.4345 - val_accuracy: 0.1679
# Epoch 272/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.5251 - accuracy: 0.8893 - val_loss: 2.4301 - val_accuracy: 0.1702
# Epoch 273/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.5130 - accuracy: 0.8908 - val_loss: 2.4256 - val_accuracy: 0.1738
# Epoch 274/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.5154 - accuracy: 0.8908 - val_loss: 2.4210 - val_accuracy: 0.1750
# Epoch 275/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.4902 - accuracy: 0.9015 - val_loss: 2.4163 - val_accuracy: 0.1762
# Epoch 276/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.4899 - accuracy: 0.9005 - val_loss: 2.4115 - val_accuracy: 0.1762
# Epoch 277/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.4909 - accuracy: 0.8985 - val_loss: 2.4067 - val_accuracy: 0.1821
# Epoch 278/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.5043 - accuracy: 0.8913 - val_loss: 2.4017 - val_accuracy: 0.1833
# Epoch 279/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.4909 - accuracy: 0.8878 - val_loss: 2.3967 - val_accuracy: 0.1857
# Epoch 280/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.4870 - accuracy: 0.9046 - val_loss: 2.3918 - val_accuracy: 0.1881
# Epoch 281/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.4747 - accuracy: 0.9041 - val_loss: 2.3868 - val_accuracy: 0.1893
# Epoch 282/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.5008 - accuracy: 0.8990 - val_loss: 2.3818 - val_accuracy: 0.1917
# Epoch 283/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.4890 - accuracy: 0.8995 - val_loss: 2.3768 - val_accuracy: 0.1940
# Epoch 284/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.5042 - accuracy: 0.8862 - val_loss: 2.3717 - val_accuracy: 0.1952
# Epoch 285/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.4874 - accuracy: 0.9066 - val_loss: 2.3664 - val_accuracy: 0.1964
# Epoch 286/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.4843 - accuracy: 0.9010 - val_loss: 2.3611 - val_accuracy: 0.2000
# Epoch 287/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.4977 - accuracy: 0.9036 - val_loss: 2.3558 - val_accuracy: 0.2012
# Epoch 288/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.4965 - accuracy: 0.8980 - val_loss: 2.3507 - val_accuracy: 0.2024
# Epoch 289/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4742 - accuracy: 0.9020 - val_loss: 2.3452 - val_accuracy: 0.2024
# Epoch 290/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.5070 - accuracy: 0.8954 - val_loss: 2.3398 - val_accuracy: 0.2060
# Epoch 291/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.4853 - accuracy: 0.9015 - val_loss: 2.3344 - val_accuracy: 0.2083
# Epoch 292/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.4949 - accuracy: 0.9077 - val_loss: 2.3289 - val_accuracy: 0.2143
# Epoch 293/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.4922 - accuracy: 0.8954 - val_loss: 2.3236 - val_accuracy: 0.2155
# Epoch 294/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.4956 - accuracy: 0.8954 - val_loss: 2.3181 - val_accuracy: 0.2167
# Epoch 295/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.4905 - accuracy: 0.8949 - val_loss: 2.3128 - val_accuracy: 0.2179
# Epoch 296/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.4996 - accuracy: 0.8918 - val_loss: 2.3072 - val_accuracy: 0.2202
# Epoch 297/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.4983 - accuracy: 0.8888 - val_loss: 2.3017 - val_accuracy: 0.2238
# Epoch 298/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.5125 - accuracy: 0.8903 - val_loss: 2.2960 - val_accuracy: 0.2250
# Epoch 299/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4842 - accuracy: 0.8980 - val_loss: 2.2902 - val_accuracy: 0.2274
# Epoch 300/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4989 - accuracy: 0.9026 - val_loss: 2.2843 - val_accuracy: 0.2274
# Epoch 301/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.4920 - accuracy: 0.8944 - val_loss: 2.2785 - val_accuracy: 0.2286
# Epoch 302/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.4941 - accuracy: 0.8893 - val_loss: 2.2727 - val_accuracy: 0.2310
# Epoch 303/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.4825 - accuracy: 0.9036 - val_loss: 2.2668 - val_accuracy: 0.2321
# Epoch 304/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.4908 - accuracy: 0.9000 - val_loss: 2.2608 - val_accuracy: 0.2345
# Epoch 305/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.4837 - accuracy: 0.9010 - val_loss: 2.2548 - val_accuracy: 0.2357
# Epoch 306/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.4827 - accuracy: 0.9051 - val_loss: 2.2489 - val_accuracy: 0.2381
# Epoch 307/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.4857 - accuracy: 0.8929 - val_loss: 2.2428 - val_accuracy: 0.2381
# Epoch 308/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.4885 - accuracy: 0.9041 - val_loss: 2.2366 - val_accuracy: 0.2405
# Epoch 309/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.5018 - accuracy: 0.8888 - val_loss: 2.2305 - val_accuracy: 0.2429
# Epoch 310/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4972 - accuracy: 0.8995 - val_loss: 2.2243 - val_accuracy: 0.2440
# Epoch 311/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.4982 - accuracy: 0.8949 - val_loss: 2.2180 - val_accuracy: 0.2488
# Epoch 312/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.4977 - accuracy: 0.8944 - val_loss: 2.2117 - val_accuracy: 0.2500
# Epoch 313/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.4753 - accuracy: 0.9031 - val_loss: 2.2052 - val_accuracy: 0.2524
# Epoch 314/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.4877 - accuracy: 0.8990 - val_loss: 2.1988 - val_accuracy: 0.2548
# Epoch 315/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.5001 - accuracy: 0.8918 - val_loss: 2.1923 - val_accuracy: 0.2571
# Epoch 316/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.4875 - accuracy: 0.8964 - val_loss: 2.1858 - val_accuracy: 0.2595
# Epoch 317/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.4865 - accuracy: 0.8995 - val_loss: 2.1792 - val_accuracy: 0.2643
# Epoch 318/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.4992 - accuracy: 0.8949 - val_loss: 2.1726 - val_accuracy: 0.2702
# Epoch 319/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.4987 - accuracy: 0.9036 - val_loss: 2.1661 - val_accuracy: 0.2702
# Epoch 320/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.4814 - accuracy: 0.8939 - val_loss: 2.1595 - val_accuracy: 0.2762
# Epoch 321/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.4829 - accuracy: 0.9046 - val_loss: 2.1528 - val_accuracy: 0.2798
# Epoch 322/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.4810 - accuracy: 0.9056 - val_loss: 2.1460 - val_accuracy: 0.2810
# Epoch 323/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.4955 - accuracy: 0.8939 - val_loss: 2.1393 - val_accuracy: 0.2833
# Epoch 324/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.4908 - accuracy: 0.9051 - val_loss: 2.1324 - val_accuracy: 0.2857
# Epoch 325/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4994 - accuracy: 0.8934 - val_loss: 2.1256 - val_accuracy: 0.2917
# Epoch 326/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.4817 - accuracy: 0.9051 - val_loss: 2.1187 - val_accuracy: 0.2952
# Epoch 327/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.4867 - accuracy: 0.9010 - val_loss: 2.1117 - val_accuracy: 0.2988
# Epoch 328/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.4898 - accuracy: 0.8918 - val_loss: 2.1047 - val_accuracy: 0.3012
# Epoch 329/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.4803 - accuracy: 0.8949 - val_loss: 2.0975 - val_accuracy: 0.3036
# Epoch 330/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.5115 - accuracy: 0.8893 - val_loss: 2.0905 - val_accuracy: 0.3036
# Epoch 331/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4852 - accuracy: 0.9020 - val_loss: 2.0833 - val_accuracy: 0.3048
# Epoch 332/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.4903 - accuracy: 0.8964 - val_loss: 2.0760 - val_accuracy: 0.3071
# Epoch 333/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.4630 - accuracy: 0.9107 - val_loss: 2.0688 - val_accuracy: 0.3095
# Epoch 334/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.4655 - accuracy: 0.9005 - val_loss: 2.0616 - val_accuracy: 0.3179
# ...
# Epoch 890/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.3784 - accuracy: 0.9270 - val_loss: 0.2767 - val_accuracy: 0.9274
# Epoch 891/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.4007 - accuracy: 0.9179 - val_loss: 0.2766 - val_accuracy: 0.9274
# Epoch 892/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.3762 - accuracy: 0.9306 - val_loss: 0.2764 - val_accuracy: 0.9274
# Epoch 893/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.3690 - accuracy: 0.9291 - val_loss: 0.2763 - val_accuracy: 0.9274
# Epoch 894/1000
# 1/1 [==============================] - 0s 374ms/step - loss: 0.3721 - accuracy: 0.9367 - val_loss: 0.2761 - val_accuracy: 0.9274
# Epoch 895/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.3912 - accuracy: 0.9255 - val_loss: 0.2760 - val_accuracy: 0.9274
# Epoch 896/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.3858 - accuracy: 0.9255 - val_loss: 0.2758 - val_accuracy: 0.9274
# Epoch 897/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.3762 - accuracy: 0.9286 - val_loss: 0.2757 - val_accuracy: 0.9274
# Epoch 898/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.3873 - accuracy: 0.9281 - val_loss: 0.2756 - val_accuracy: 0.9274
# Epoch 899/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.3590 - accuracy: 0.9388 - val_loss: 0.2755 - val_accuracy: 0.9274
# Epoch 900/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.3700 - accuracy: 0.9393 - val_loss: 0.2754 - val_accuracy: 0.9274
# Epoch 901/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.3553 - accuracy: 0.9347 - val_loss: 0.2754 - val_accuracy: 0.9262
# Epoch 902/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.3780 - accuracy: 0.9301 - val_loss: 0.2753 - val_accuracy: 0.9262
# Epoch 903/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.3669 - accuracy: 0.9357 - val_loss: 0.2752 - val_accuracy: 0.9262
# Epoch 904/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.3789 - accuracy: 0.9255 - val_loss: 0.2751 - val_accuracy: 0.9262
# Epoch 905/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.3843 - accuracy: 0.9367 - val_loss: 0.2750 - val_accuracy: 0.9262
# Epoch 906/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.3815 - accuracy: 0.9199 - val_loss: 0.2749 - val_accuracy: 0.9262
# Epoch 907/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.3717 - accuracy: 0.9321 - val_loss: 0.2748 - val_accuracy: 0.9262
# Epoch 908/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.3888 - accuracy: 0.9265 - val_loss: 0.2747 - val_accuracy: 0.9262
# Epoch 909/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.3622 - accuracy: 0.9357 - val_loss: 0.2746 - val_accuracy: 0.9262
# Epoch 910/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.3926 - accuracy: 0.9235 - val_loss: 0.2745 - val_accuracy: 0.9262
# Epoch 911/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.3724 - accuracy: 0.9347 - val_loss: 0.2744 - val_accuracy: 0.9262
# Epoch 912/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.3688 - accuracy: 0.9316 - val_loss: 0.2742 - val_accuracy: 0.9262
# Epoch 913/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.3738 - accuracy: 0.9316 - val_loss: 0.2741 - val_accuracy: 0.9262
# Epoch 914/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.3710 - accuracy: 0.9311 - val_loss: 0.2740 - val_accuracy: 0.9262
# Epoch 915/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.3728 - accuracy: 0.9337 - val_loss: 0.2739 - val_accuracy: 0.9262
# Epoch 916/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.3703 - accuracy: 0.9311 - val_loss: 0.2737 - val_accuracy: 0.9262
# Epoch 917/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.3780 - accuracy: 0.9311 - val_loss: 0.2735 - val_accuracy: 0.9262
# Epoch 918/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.3726 - accuracy: 0.9301 - val_loss: 0.2733 - val_accuracy: 0.9262
# Epoch 919/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.3544 - accuracy: 0.9352 - val_loss: 0.2732 - val_accuracy: 0.9262
# Epoch 920/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.3594 - accuracy: 0.9316 - val_loss: 0.2730 - val_accuracy: 0.9262
# Epoch 921/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.3865 - accuracy: 0.9270 - val_loss: 0.2729 - val_accuracy: 0.9262
# Epoch 922/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.3829 - accuracy: 0.9194 - val_loss: 0.2728 - val_accuracy: 0.9262
# Epoch 923/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.3711 - accuracy: 0.9372 - val_loss: 0.2726 - val_accuracy: 0.9262
# Epoch 924/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.3530 - accuracy: 0.9321 - val_loss: 0.2725 - val_accuracy: 0.9262
# Epoch 925/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.3809 - accuracy: 0.9352 - val_loss: 0.2723 - val_accuracy: 0.9262
# Epoch 926/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.3677 - accuracy: 0.9332 - val_loss: 0.2722 - val_accuracy: 0.9262
# Epoch 927/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.3822 - accuracy: 0.9281 - val_loss: 0.2720 - val_accuracy: 0.9262
# Epoch 928/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.3743 - accuracy: 0.9240 - val_loss: 0.2719 - val_accuracy: 0.9262
# Epoch 929/1000
# 1/1 [==============================] - 0s 368ms/step - loss: 0.3723 - accuracy: 0.9265 - val_loss: 0.2718 - val_accuracy: 0.9262
# Epoch 930/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.3819 - accuracy: 0.9291 - val_loss: 0.2717 - val_accuracy: 0.9262
# Epoch 931/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.3845 - accuracy: 0.9235 - val_loss: 0.2716 - val_accuracy: 0.9262
# Epoch 932/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.3693 - accuracy: 0.9321 - val_loss: 0.2715 - val_accuracy: 0.9262
# Epoch 933/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.3744 - accuracy: 0.9316 - val_loss: 0.2714 - val_accuracy: 0.9262
# Epoch 934/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.3683 - accuracy: 0.9316 - val_loss: 0.2712 - val_accuracy: 0.9262
# Epoch 935/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.3718 - accuracy: 0.9398 - val_loss: 0.2712 - val_accuracy: 0.9262
# Epoch 936/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.3552 - accuracy: 0.9352 - val_loss: 0.2711 - val_accuracy: 0.9262
# Epoch 937/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.3568 - accuracy: 0.9383 - val_loss: 0.2711 - val_accuracy: 0.9262
# Epoch 938/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.3687 - accuracy: 0.9372 - val_loss: 0.2710 - val_accuracy: 0.9262
# Epoch 939/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.3600 - accuracy: 0.9321 - val_loss: 0.2710 - val_accuracy: 0.9262
# Epoch 940/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.3531 - accuracy: 0.9413 - val_loss: 0.2709 - val_accuracy: 0.9262
# Epoch 941/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.3628 - accuracy: 0.9357 - val_loss: 0.2708 - val_accuracy: 0.9262
# Epoch 942/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.3723 - accuracy: 0.9332 - val_loss: 0.2707 - val_accuracy: 0.9274
# Epoch 943/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.3716 - accuracy: 0.9347 - val_loss: 0.2706 - val_accuracy: 0.9274
# Epoch 944/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.3581 - accuracy: 0.9352 - val_loss: 0.2704 - val_accuracy: 0.9274
# Epoch 945/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.3875 - accuracy: 0.9168 - val_loss: 0.2703 - val_accuracy: 0.9274
# Epoch 946/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.3655 - accuracy: 0.9367 - val_loss: 0.2702 - val_accuracy: 0.9274
# Epoch 947/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.3650 - accuracy: 0.9367 - val_loss: 0.2701 - val_accuracy: 0.9274
# Epoch 948/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.3620 - accuracy: 0.9316 - val_loss: 0.2700 - val_accuracy: 0.9274
# Epoch 949/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.3503 - accuracy: 0.9398 - val_loss: 0.2699 - val_accuracy: 0.9274
# Epoch 950/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.3686 - accuracy: 0.9352 - val_loss: 0.2698 - val_accuracy: 0.9274
# Epoch 951/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.3611 - accuracy: 0.9408 - val_loss: 0.2697 - val_accuracy: 0.9274
# Epoch 952/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.3673 - accuracy: 0.9286 - val_loss: 0.2696 - val_accuracy: 0.9274
# Epoch 953/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.3727 - accuracy: 0.9327 - val_loss: 0.2695 - val_accuracy: 0.9274
# Epoch 954/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.3536 - accuracy: 0.9362 - val_loss: 0.2694 - val_accuracy: 0.9274
# Epoch 955/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.3747 - accuracy: 0.9352 - val_loss: 0.2694 - val_accuracy: 0.9274
# Epoch 956/1000
# 1/1 [==============================] - 0s 372ms/step - loss: 0.3637 - accuracy: 0.9413 - val_loss: 0.2693 - val_accuracy: 0.9274
# Epoch 957/1000
# 1/1 [==============================] - 0s 361ms/step - loss: 0.3584 - accuracy: 0.9403 - val_loss: 0.2692 - val_accuracy: 0.9274
# Epoch 958/1000
# 1/1 [==============================] - 0s 359ms/step - loss: 0.3590 - accuracy: 0.9372 - val_loss: 0.2691 - val_accuracy: 0.9274
# Epoch 959/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.3615 - accuracy: 0.9403 - val_loss: 0.2691 - val_accuracy: 0.9274
# Epoch 960/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.3623 - accuracy: 0.9332 - val_loss: 0.2690 - val_accuracy: 0.9274
# Epoch 961/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.3704 - accuracy: 0.9281 - val_loss: 0.2690 - val_accuracy: 0.9274
# Epoch 962/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.3735 - accuracy: 0.9270 - val_loss: 0.2689 - val_accuracy: 0.9274
# Epoch 963/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.3563 - accuracy: 0.9311 - val_loss: 0.2688 - val_accuracy: 0.9274
# Epoch 964/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.3859 - accuracy: 0.9286 - val_loss: 0.2688 - val_accuracy: 0.9274
# Epoch 965/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.3682 - accuracy: 0.9321 - val_loss: 0.2687 - val_accuracy: 0.9274
# Epoch 966/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.3593 - accuracy: 0.9332 - val_loss: 0.2686 - val_accuracy: 0.9274
# Epoch 967/1000
# 1/1 [==============================] - 0s 369ms/step - loss: 0.3532 - accuracy: 0.9352 - val_loss: 0.2686 - val_accuracy: 0.9274
# Epoch 968/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.3616 - accuracy: 0.9342 - val_loss: 0.2685 - val_accuracy: 0.9274
# Epoch 969/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.3678 - accuracy: 0.9357 - val_loss: 0.2684 - val_accuracy: 0.9274
# Epoch 970/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.3776 - accuracy: 0.9291 - val_loss: 0.2683 - val_accuracy: 0.9274
# Epoch 971/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.3608 - accuracy: 0.9357 - val_loss: 0.2683 - val_accuracy: 0.9274
# Epoch 972/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.3644 - accuracy: 0.9367 - val_loss: 0.2682 - val_accuracy: 0.9262
# Epoch 973/1000
# 1/1 [==============================] - 0s 373ms/step - loss: 0.3694 - accuracy: 0.9337 - val_loss: 0.2682 - val_accuracy: 0.9262
# Epoch 974/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.3535 - accuracy: 0.9337 - val_loss: 0.2681 - val_accuracy: 0.9262
# Epoch 975/1000
# 1/1 [==============================] - 0s 364ms/step - loss: 0.3657 - accuracy: 0.9383 - val_loss: 0.2681 - val_accuracy: 0.9262
# Epoch 976/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.3422 - accuracy: 0.9464 - val_loss: 0.2680 - val_accuracy: 0.9262
# Epoch 977/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.3715 - accuracy: 0.9311 - val_loss: 0.2679 - val_accuracy: 0.9262
# Epoch 978/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.3551 - accuracy: 0.9372 - val_loss: 0.2678 - val_accuracy: 0.9262
# Epoch 979/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.3570 - accuracy: 0.9388 - val_loss: 0.2678 - val_accuracy: 0.9262
# Epoch 980/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.3682 - accuracy: 0.9332 - val_loss: 0.2676 - val_accuracy: 0.9262
# Epoch 981/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.3477 - accuracy: 0.9408 - val_loss: 0.2675 - val_accuracy: 0.9262
# Epoch 982/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.3616 - accuracy: 0.9347 - val_loss: 0.2674 - val_accuracy: 0.9262
# Epoch 983/1000
# 1/1 [==============================] - 0s 362ms/step - loss: 0.3656 - accuracy: 0.9316 - val_loss: 0.2673 - val_accuracy: 0.9262
# Epoch 984/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.3726 - accuracy: 0.9316 - val_loss: 0.2672 - val_accuracy: 0.9262
# Epoch 985/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.3652 - accuracy: 0.9301 - val_loss: 0.2672 - val_accuracy: 0.9262
# Epoch 986/1000
# 1/1 [==============================] - 0s 365ms/step - loss: 0.3550 - accuracy: 0.9362 - val_loss: 0.2671 - val_accuracy: 0.9262
# Epoch 987/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.3664 - accuracy: 0.9357 - val_loss: 0.2670 - val_accuracy: 0.9262
# Epoch 988/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 0.3564 - accuracy: 0.9327 - val_loss: 0.2669 - val_accuracy: 0.9262
# Epoch 989/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.3498 - accuracy: 0.9480 - val_loss: 0.2669 - val_accuracy: 0.9262
# Epoch 990/1000
# 1/1 [==============================] - 0s 367ms/step - loss: 0.3673 - accuracy: 0.9265 - val_loss: 0.2668 - val_accuracy: 0.9262
# Epoch 991/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.3538 - accuracy: 0.9316 - val_loss: 0.2667 - val_accuracy: 0.9262
# Epoch 992/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.3570 - accuracy: 0.9321 - val_loss: 0.2666 - val_accuracy: 0.9262
# Epoch 993/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.3524 - accuracy: 0.9378 - val_loss: 0.2665 - val_accuracy: 0.9262
# Epoch 994/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.3544 - accuracy: 0.9408 - val_loss: 0.2664 - val_accuracy: 0.9262
# Epoch 995/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.3516 - accuracy: 0.9388 - val_loss: 0.2663 - val_accuracy: 0.9262
# Epoch 996/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.3703 - accuracy: 0.9372 - val_loss: 0.2663 - val_accuracy: 0.9262
# Epoch 997/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.3711 - accuracy: 0.9281 - val_loss: 0.2662 - val_accuracy: 0.9262
# Epoch 998/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.3496 - accuracy: 0.9383 - val_loss: 0.2661 - val_accuracy: 0.9262
# Epoch 999/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.3491 - accuracy: 0.9388 - val_loss: 0.2661 - val_accuracy: 0.9262
# Epoch 1000/1000
# 1/1 [==============================] - 0s 363ms/step - loss: 0.3712 - accuracy: 0.9311 - val_loss: 0.2660 - val_accuracy: 0.9262

# %% [markdown]
# 6.Plotting results

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
Y_pred = DD_Net.predict([X_test_0,X_test_1])
labels = ['Grab', 'Tap', 'Expand', 'Pinch', 'RC', 'RCC', 'SR', 'SL', 'SU', 'SD', 'SX', 'S+', 'SV', 'Shake']

y_true = []
for i in np.argmax(Y_test,axis=1):
    y_true.append(labels[i])
    
y_pred = []
for i in np.argmax(Y_pred,axis=1):
    y_pred.append(labels[i])

cm_analysis(y_true,y_pred, 'SHREC_14.png', labels, ymap=None, figsize=(8,8))

# %%
DD_Net.save('DD_Net_large_14.h5')
